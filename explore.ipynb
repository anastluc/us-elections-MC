# %%
import pandas as pd

# %%
df = pd.read_csv("president_polls.csv")
df.head()
# Out:
#    poll_id  pollster_id          pollster sponsor_ids sponsors  \
# 0    88450          235  InsiderAdvantage         NaN      NaN
# 1    88450          235  InsiderAdvantage         NaN      NaN
# 2    88451          235  InsiderAdvantage         NaN      NaN
# 3    88451          235  InsiderAdvantage         NaN      NaN
# 4    88452          235  InsiderAdvantage         NaN      NaN
#
#        display_name  pollster_rating_id pollster_rating_name  numeric_grade  \
# 0  InsiderAdvantage                 243     InsiderAdvantage            2.0
# 1  InsiderAdvantage                 243     InsiderAdvantage            2.0
# 2  InsiderAdvantage                 243     InsiderAdvantage            2.0
# 3  InsiderAdvantage                 243     InsiderAdvantage            2.0
# 4  InsiderAdvantage                 243     InsiderAdvantage            2.0
#
#    pollscore  ... election_date    stage nationwide_batch  \
# 0       -0.3  ...       11/5/24  general            False
# 1       -0.3  ...       11/5/24  general            False
# 2       -0.3  ...       11/5/24  general            False
# 3       -0.3  ...       11/5/24  general            False
# 4       -0.3  ...       11/5/24  general            False
#
#   ranked_choice_reallocated ranked_choice_round  party  answer candidate_id  \
# 0                     False                 NaN    DEM  Harris        16661
# 1                     False                 NaN    REP   Trump        16651
# 2                     False                 NaN    DEM  Harris        16661
# 3                     False                 NaN    REP   Trump        16651
# 4                     False                 NaN    DEM  Harris        16661
#
#    candidate_name   pct
# 0   Kamala Harris  48.0
# 1    Donald Trump  49.0
# 2   Kamala Harris  48.0
# 3    Donald Trump  49.0
# 4   Kamala Harris  49.0
#
# [5 rows x 51 columns]

# %%
df.columns
# Out:
# Index(['poll_id', 'pollster_id', 'pollster', 'sponsor_ids', 'sponsors',
#        'display_name', 'pollster_rating_id', 'pollster_rating_name',
#        'numeric_grade', 'pollscore', 'methodology', 'transparency_score',
#        'state', 'start_date', 'end_date', 'sponsor_candidate_id',
#        'sponsor_candidate', 'sponsor_candidate_party', 'endorsed_candidate_id',
#        'endorsed_candidate_name', 'endorsed_candidate_party', 'question_id',
#        'sample_size', 'population', 'subpopulation', 'population_full',
#        'tracking', 'created_at', 'notes', 'url', 'url_article', 'url_topline',
#        'url_crosstab', 'source', 'internal', 'partisan', 'race_id', 'cycle',
#        'office_type', 'seat_number', 'seat_name', 'election_date', 'stage',
#        'nationwide_batch', 'ranked_choice_reallocated', 'ranked_choice_round',
#        'party', 'answer', 'candidate_id', 'candidate_name', 'pct'],
#       dtype='object')

# %%
df["state"].unique()
# Out:
# array(['Arizona', 'Nevada', 'North Carolina', 'Georgia', 'New York',
#        'Ohio', 'Indiana', 'Pennsylvania', nan, 'Alaska', 'Wisconsin',
#        'Texas', 'Michigan', 'Florida', 'Nebraska CD-2', 'Minnesota',
#        'North Dakota', 'California', 'Virginia', 'Nebraska', 'Maryland',
#        'Delaware', 'Rhode Island', 'Montana', 'Massachusetts',
#        'New Mexico', 'Connecticut', 'Colorado', 'New Hampshire', 'Maine',
#        'Maine CD-1', 'Maine CD-2', 'Missouri', 'Iowa', 'Arkansas',
#        'Washington', 'Oklahoma', 'Illinois', 'Tennessee', 'West Virginia',
#        'Vermont', 'Utah', 'Oregon', 'New Jersey', 'South Dakota',
#        'Louisiana', 'Hawaii', 'Alabama', 'Idaho', 'Kansas', 'Kentucky',
#        'Mississippi', 'South Carolina', 'Wyoming'], dtype=object)

# %%
len(df["state"].unique())
# Out:
# 54

# %%
electoral = """
Alabama - 9 votes

Kentucky - 8 votes

North Dakota - 3 votes

Alaska - 3 votes

Louisiana - 8 votes

Ohio - 17 votes

Arizona - 11 votes

Maine - 4 votes

Oklahoma - 7 votes

Arkansas - 6 votes

Maryland - 10 votes

Oregon - 8 votes

California - 54 votes

Massachusetts - 11 votes

Pennsylvania - 19 votes

Colorado - 10 votes

Michigan - 15 votes

Rhode Island - 4 votes

Connecticut - 7 votes

Minnesota - 10 votes

South Carolina - 9 votes

Delaware - 3 votes

Mississippi - 6 votes

South Dakota - 3 votes

District of Columbia - 3 votes

Missouri - 10 votes

Tennessee - 11 votes

Florida - 30 votes

Montana - 4 votes

Texas - 40 votes

Georgia - 16 votes

Nebraska - 5 votes

Utah - 6 votes

Hawaii - 4 votes

Nevada - 6 votes

Vermont - 3 votes

Idaho - 4 votes

New Hampshire - 4 votes

Virginia - 13 votes

Illinois - 19 votes

New Jersey - 14 votes

Washington - 12 votes

Indiana - 11 votes

New Mexico - 5 votes

West Virginia - 4 votes

Iowa - 6 votes

New York - 28 votes

Wisconsin - 10 votes

Kansas - 6 votes

North Carolina - 16 votes

Wyoming - 3 votes
"""

# %%
ele_list = electoral.split("\n")

# %%
ele_list = [item for item in ele_list if item!=""]
ele_list
# Out:
# ['Alabama - 9 votes',
#  'Kentucky - 8 votes',
#  'North Dakota - 3 votes',
#  'Alaska - 3 votes',
#  'Louisiana - 8 votes',
#  'Ohio - 17 votes',
#  'Arizona - 11 votes',
#  'Maine - 4 votes',
#  'Oklahoma - 7 votes',
#  'Arkansas - 6 votes',
#  'Maryland - 10 votes',
#  'Oregon - 8 votes',
#  'California - 54 votes',
#  'Massachusetts - 11 votes',
#  'Pennsylvania - 19 votes',
#  'Colorado - 10 votes',
#  'Michigan - 15 votes',
#  'Rhode Island - 4 votes',
#  'Connecticut - 7 votes',
#  'Minnesota - 10 votes',
#  'South Carolina - 9 votes',
#  'Delaware - 3 votes',
#  'Mississippi - 6 votes',
#  'South Dakota - 3 votes',
#  'District of Columbia - 3 votes',
#  'Missouri - 10 votes',
#  'Tennessee - 11 votes',
#  'Florida - 30 votes',
#  'Montana - 4 votes',
#  'Texas - 40 votes',
#  'Georgia - 16 votes',
#  'Nebraska - 5 votes',
#  'Utah - 6 votes',
#  'Hawaii - 4 votes',
#  'Nevada - 6 votes',
#  'Vermont - 3 votes',
#  'Idaho - 4 votes',
#  'New Hampshire - 4 votes',
#  'Virginia - 13 votes',
#  'Illinois - 19 votes',
#  'New Jersey - 14 votes',
#  'Washington - 12 votes',
#  'Indiana - 11 votes',
#  'New Mexico - 5 votes',
#  'West Virginia - 4 votes',
#  'Iowa - 6 votes',
#  'New York - 28 votes',
#  'Wisconsin - 10 votes',
#  'Kansas - 6 votes',
#  'North Carolina - 16 votes',
#  'Wyoming - 3 votes']

# %%
def parse_state_votes(state_vote_list):
    result = []
    for item in state_vote_list:
        # Split the string into state and votes parts
        parts = item.split(' - ')
        if len(parts) == 2:
            state = parts[0]
            # Extract the number of votes and convert to integer
            votes = int(parts[1].split()[0])
            # Create a dictionary and append to result
            result.append({"state": state, "votes": votes})
    return result

# %%
parsed_list = parse_state_votes(ele_list)

# %%
parsed_list
# Out:
# [{'state': 'Alabama', 'votes': 9},
#  {'state': 'Kentucky', 'votes': 8},
#  {'state': 'North Dakota', 'votes': 3},
#  {'state': 'Alaska', 'votes': 3},
#  {'state': 'Louisiana', 'votes': 8},
#  {'state': 'Ohio', 'votes': 17},
#  {'state': 'Arizona', 'votes': 11},
#  {'state': 'Maine', 'votes': 4},
#  {'state': 'Oklahoma', 'votes': 7},
#  {'state': 'Arkansas', 'votes': 6},
#  {'state': 'Maryland', 'votes': 10},
#  {'state': 'Oregon', 'votes': 8},
#  {'state': 'California', 'votes': 54},
#  {'state': 'Massachusetts', 'votes': 11},
#  {'state': 'Pennsylvania', 'votes': 19},
#  {'state': 'Colorado', 'votes': 10},
#  {'state': 'Michigan', 'votes': 15},
#  {'state': 'Rhode Island', 'votes': 4},
#  {'state': 'Connecticut', 'votes': 7},
#  {'state': 'Minnesota', 'votes': 10},
#  {'state': 'South Carolina', 'votes': 9},
#  {'state': 'Delaware', 'votes': 3},
#  {'state': 'Mississippi', 'votes': 6},
#  {'state': 'South Dakota', 'votes': 3},
#  {'state': 'District of Columbia', 'votes': 3},
#  {'state': 'Missouri', 'votes': 10},
#  {'state': 'Tennessee', 'votes': 11},
#  {'state': 'Florida', 'votes': 30},
#  {'state': 'Montana', 'votes': 4},
#  {'state': 'Texas', 'votes': 40},
#  {'state': 'Georgia', 'votes': 16},
#  {'state': 'Nebraska', 'votes': 5},
#  {'state': 'Utah', 'votes': 6},
#  {'state': 'Hawaii', 'votes': 4},
#  {'state': 'Nevada', 'votes': 6},
#  {'state': 'Vermont', 'votes': 3},
#  {'state': 'Idaho', 'votes': 4},
#  {'state': 'New Hampshire', 'votes': 4},
#  {'state': 'Virginia', 'votes': 13},
#  {'state': 'Illinois', 'votes': 19},
#  {'state': 'New Jersey', 'votes': 14},
#  {'state': 'Washington', 'votes': 12},
#  {'state': 'Indiana', 'votes': 11},
#  {'state': 'New Mexico', 'votes': 5},
#  {'state': 'West Virginia', 'votes': 4},
#  {'state': 'Iowa', 'votes': 6},
#  {'state': 'New York', 'votes': 28},
#  {'state': 'Wisconsin', 'votes': 10},
#  {'state': 'Kansas', 'votes': 6},
#  {'state': 'North Carolina', 'votes': 16},
#  {'state': 'Wyoming', 'votes': 3}]

# %%
len(parsed_list)
# Out:
# 51

# %%
df[df["state"]=="North Carolina"]
# Out:
#        poll_id  pollster_id                    pollster sponsor_ids  \
# 4        88452          235            InsiderAdvantage         NaN
# 5        88452          235            InsiderAdvantage         NaN
# 27       88431          486         The Washington Post         NaN
# 28       88431          486         The Washington Post         NaN
# 29       88431          486         The Washington Post         NaN
# ...        ...          ...                         ...         ...
# 14115    79648         1702           Blueprint Polling         NaN
# 14158    79518         1674  PEM Management Corporation        1629
# 14159    79518         1674  PEM Management Corporation        1629
# 14298    78997         1516    East Carolina University         NaN
# 14299    78997         1516    East Carolina University         NaN
#
#                     sponsors  \
# 4                        NaN
# 5                        NaN
# 27                       NaN
# 28                       NaN
# 29                       NaN
# ...                      ...
# 14115                    NaN
# 14158  John Bolton Super PAC
# 14159  John Bolton Super PAC
# 14298                    NaN
# 14299                    NaN
#
#                                             display_name  pollster_rating_id  \
# 4                                       InsiderAdvantage                 243
# 5                                       InsiderAdvantage                 243
# 27                                   The Washington Post                   3
# 28                                   The Washington Post                   3
# 29                                   The Washington Post                   3
# ...                                                  ...                 ...
# 14115                                  Blueprint Polling                 470
# 14158                         PEM Management Corporation                 675
# 14159                         PEM Management Corporation                 675
# 14298  East Carolina University Center for Survey Res...                 523
# 14299  East Carolina University Center for Survey Res...                 523
#
#                                     pollster_rating_name  numeric_grade  \
# 4                                       InsiderAdvantage            2.0
# 5                                       InsiderAdvantage            2.0
# 27                          ABC News/The Washington Post            3.0
# 28                          ABC News/The Washington Post            3.0
# 29                          ABC News/The Washington Post            3.0
# ...                                                  ...            ...
# 14115                                  Blueprint Polling            2.4
# 14158                         PEM Management Corporation            NaN
# 14159                         PEM Management Corporation            NaN
# 14298  East Carolina University Center for Survey Res...            2.6
# 14299  East Carolina University Center for Survey Res...            2.6
#
#        pollscore  ... election_date    stage nationwide_batch  \
# 4           -0.3  ...       11/5/24  general            False
# 5           -0.3  ...       11/5/24  general            False
# 27          -1.2  ...       11/5/24  general            False
# 28          -1.2  ...       11/5/24  general            False
# 29          -1.2  ...       11/5/24  general            False
# ...          ...  ...           ...      ...              ...
# 14115       -0.3  ...       11/5/24  general            False
# 14158        NaN  ...       11/5/24  general            False
# 14159        NaN  ...       11/5/24  general            False
# 14298       -0.5  ...       11/5/24  general            False
# 14299       -0.5  ...       11/5/24  general            False
#
#       ranked_choice_reallocated ranked_choice_round  party  answer  \
# 4                         False                 NaN    DEM  Harris
# 5                         False                 NaN    REP   Trump
# 27                        False                 NaN    DEM  Harris
# 28                        False                 NaN    REP   Trump
# 29                        False                 NaN    DEM  Harris
# ...                         ...                 ...    ...     ...
# 14115                     False                 NaN    REP   Trump
# 14158                     False                 NaN    DEM   Biden
# 14159                     False                 NaN    REP   Trump
# 14298                     False                 NaN    DEM   Biden
# 14299                     False                 NaN    REP   Trump
#
#       candidate_id  candidate_name   pct
# 4            16661   Kamala Harris  49.0
# 5            16651    Donald Trump  50.0
# 27           16661   Kamala Harris  48.0
# 28           16651    Donald Trump  50.0
# 29           16661   Kamala Harris  47.0
# ...            ...             ...   ...
# 14115        16651    Donald Trump  45.0
# 14158        19368       Joe Biden  40.7
# 14159        16651    Donald Trump  48.0
# 14298        19368       Joe Biden  37.2
# 14299        16651    Donald Trump  46.4
#
# [586 rows x 51 columns]

# %%
import pandas as pd

def getLatestPollOfStateAndCandidate(df, state, candidateA, candidateB, verbose =True ):
    # Filter the dataframe for the given state and candidate
    state_candidate_polls = df[(df['state'] == state) & ((df['answer'] == candidateA) | (df['answer'] == candidateB)  )]
    
    if state_candidate_polls.empty:
        if verbose:
            print(f"No polls found for {candidateA} or {candidateB} in {state}")
        return None
    
    # Sort by end_date in descending order and get the first row
    latest_poll = state_candidate_polls.sort_values('end_date', ascending=False).iloc[0]
    
    return {
        'state': state,
        'candidate': candidateA,
        'percentage': latest_poll['pct'],
        'poll_date': latest_poll['end_date']
    }

# %%
df = pd.read_csv("president_polls.csv")

# %%
getLatestPollOfStateAndCandidate(df,"Alaska","Trump","Trump")
# Out:
# {'state': 'Alaska',
#  'candidate': 'Trump',
#  'percentage': np.float64(52.0),
#  'poll_date': '9/29/24'}

# %%
getLatestPollOfStateAndCandidate(df,"Alaska","Harris","Biden")
# Out:
# {'state': 'Alaska',
#  'candidate': 'Harris',
#  'percentage': np.float64(43.0),
#  'poll_date': '9/29/24'}

# %%
def simulate_election(parsed_list, poll_data):
    results = {}
    total_votes_a = 0
    total_votes_b = 0

    for state_info in parsed_list:
        state = state_info['state']
        votes = state_info['votes']

        candidate_a_result = getLatestPollOfStateAndCandidate(poll_data, state, "Trump","Trump")
        candidate_b_result = getLatestPollOfStateAndCandidate(poll_data, state, "Harris","Biden")

        if candidate_a_result and candidate_b_result:
            pct_a = candidate_a_result['percentage']
            pct_b = candidate_b_result['percentage']
            
            results[state] = {
                'Trump': pct_a,
                'Harris': pct_b,
                'votes': votes,
                'winner': 'Trump' if pct_a > pct_b else 'Harris',
                'date': max(candidate_a_result['poll_date'], candidate_b_result['poll_date'])
            }
            
            if pct_a > pct_b:
                total_votes_a += votes
            else:
                total_votes_b += votes
        else:
            print(f"Couldn't find poll data for both candidates in {state}")
    
    return results, total_votes_a, total_votes_b

# %%
results, votes_a, votes_b = simulate_election(parsed_list, df)
# Out:
# No polls found for Trump or Trump in District of Columbia
# No polls found for Harris or Biden in District of Columbia
# Couldn't find poll data for both candidates in District of Columbia

# %%
votes_a, votes_b
# Out:
# (266, 269)

# %%
import math
def election_probability(pa, pb, moe, uv):
    # Adjust for undecided voters
    total = pa + pb
    adj_pa = pa / total * (100 - uv)
    adj_pb = pb / total * (100 - uv)
    
    # Calculate spread
    spread = adj_pa - adj_pb
    
    # Calculate standard error
    se = moe / 1.96
    
    # Calculate z-score
    z = spread / (se * math.sqrt(2))
    
    # Use error function to calculate probability
    probability = 0.5 * (1 + math.erf(z / math.sqrt(2)))
    
    return probability * 100

# %%
election_probability(51,49,20,00)
# Out:
# 55.51140844322191

# %%
import random

def simulate_election_with_probability(parsed_list, poll_data, verbose = True):
    results = {}
    total_votes_a = 0
    total_votes_b = 0

    for state_info in parsed_list:
        state = state_info['state']
        votes = state_info['votes']

        candidate_a_result = getLatestPollOfStateAndCandidate(poll_data, state, "Trump","Trump" , verbose=verbose)
        candidate_b_result = getLatestPollOfStateAndCandidate(poll_data, state, "Harris","Biden" , verbose=verbose)

        if candidate_a_result and candidate_b_result:
            pct_a = candidate_a_result['percentage']
            pct_b = candidate_b_result['percentage']

            election_probability_a = election_probability(pct_a,pct_b,5,0)
            election_probability_b = 100 - election_probability_a

            winner_a = random.random()*100 < election_probability_a
            winner_b = not winner_a
            winner_str = "Trump" if winner_a else "Harris"

            if verbose:
                print(f"{state} pct(trump|harris):{pct_a:.1f}|{pct_b:.1f} probs:{election_probability_a:.1f}|{election_probability_b:.1f} winner:{winner_str}")
            
            results[state] = {
                'Trump': pct_a,
                'Harris': pct_b,
                'votes': votes,
                'winner': 'Trump' if winner_a else 'Harris', #if pct_a > pct_b else 'Harris',
                'date': max(candidate_a_result['poll_date'], candidate_b_result['poll_date'])
            }
            
            if winner_a:#pct_a > pct_b:
                total_votes_a += votes
            else:
                total_votes_b += votes
        else:
            if verbose:
                print(f"Couldn't find poll data for both candidates in {state}")
    
    return results, total_votes_a, total_votes_b

# %%
results, votes_a, votes_b = simulate_election_with_probability(parsed_list, df)
# Out:
# Alabama pct(trump|harris):57.0|32.0 probs:100.0|0.0 winner:Trump
# Kentucky pct(trump|harris):55.0|34.0 probs:100.0|0.0 winner:Trump
# North Dakota pct(trump|harris):50.0|40.0 probs:99.9|0.1 winner:Trump
# Alaska pct(trump|harris):52.0|43.0 probs:99.6|0.4 winner:Trump
# Louisiana pct(trump|harris):51.0|36.0 probs:100.0|0.0 winner:Trump
# Ohio pct(trump|harris):51.9|43.6 probs:99.2|0.8 winner:Trump
# Arizona pct(trump|harris):46.2|46.0 probs:52.4|47.6 winner:Trump
# Maine pct(trump|harris):40.1|50.9 probs:0.1|99.9 winner:Harris
# Oklahoma pct(trump|harris):63.0|30.0 probs:100.0|0.0 winner:Trump
# Arkansas pct(trump|harris):58.0|33.0 probs:100.0|0.0 winner:Trump
# Maryland pct(trump|harris):34.1|62.2 probs:0.0|100.0 winner:Harris
# Oregon pct(trump|harris):44.0|49.0 probs:6.8|93.2 winner:Harris
# California pct(trump|harris):29.0|60.0 probs:0.0|100.0 winner:Harris
# Massachusetts pct(trump|harris):33.7|54.0 probs:0.0|100.0 winner:Harris
# Pennsylvania pct(trump|harris):45.0|45.0 probs:50.0|50.0 winner:Trump
# Colorado pct(trump|harris):40.1|54.8 probs:0.0|100.0 winner:Harris
# Michigan pct(trump|harris):45.0|48.0 probs:18.6|81.4 winner:Trump
# Rhode Island pct(trump|harris):37.0|51.0 probs:0.0|100.0 winner:Harris
# Connecticut pct(trump|harris):35.7|49.0 probs:0.0|100.0 winner:Harris
# Minnesota pct(trump|harris):44.0|51.0 probs:2.1|97.9 winner:Harris
# South Carolina pct(trump|harris):51.0|39.0 probs:100.0|0.0 winner:Trump
# Delaware pct(trump|harris):37.0|54.0 probs:0.0|100.0 winner:Harris
# Mississippi pct(trump|harris):54.0|36.0 probs:100.0|0.0 winner:Trump
# South Dakota pct(trump|harris):50.0|31.4 probs:100.0|0.0 winner:Trump
# No polls found for Trump or Trump in District of Columbia
# No polls found for Harris or Biden in District of Columbia
# Couldn't find poll data for both candidates in District of Columbia
# Missouri pct(trump|harris):51.4|37.0 probs:100.0|0.0 winner:Trump
# Tennessee pct(trump|harris):63.1|36.9 probs:100.0|0.0 winner:Trump
# Florida pct(trump|harris):50.0|44.0 probs:96.2|3.8 winner:Trump
# Montana pct(trump|harris):49.0|35.0 probs:100.0|0.0 winner:Trump
# Texas pct(trump|harris):51.8|43.4 probs:99.2|0.8 winner:Trump
# Georgia pct(trump|harris):49.0|47.0 probs:71.8|28.2 winner:Trump
# Nebraska pct(trump|harris):56.0|40.0 probs:100.0|0.0 winner:Trump
# Utah pct(trump|harris):51.0|25.0 probs:100.0|0.0 winner:Trump
# Hawaii pct(trump|harris):38.0|57.0 probs:0.0|100.0 winner:Harris
# Nevada pct(trump|harris):46.0|45.0 probs:62.0|38.0 winner:Harris
# Vermont pct(trump|harris):27.0|67.0 probs:0.0|100.0 winner:Harris
# Idaho pct(trump|harris):53.8|24.6 probs:100.0|0.0 winner:Trump
# New Hampshire pct(trump|harris):40.0|47.0 probs:1.3|98.7 winner:Harris
# Virginia pct(trump|harris):44.0|44.0 probs:50.0|50.0 winner:Trump
# Illinois pct(trump|harris):38.3|51.0 probs:0.0|100.0 winner:Harris
# New Jersey pct(trump|harris):41.0|40.0 probs:63.4|36.6 winner:Harris
# Washington pct(trump|harris):32.0|53.0 probs:0.0|100.0 winner:Harris
# Indiana pct(trump|harris):57.0|43.0 probs:100.0|0.0 winner:Trump
# New Mexico pct(trump|harris):44.0|49.0 probs:6.8|93.2 winner:Harris
# West Virginia pct(trump|harris):61.0|34.0 probs:100.0|0.0 winner:Trump
# Iowa pct(trump|harris):50.0|34.5 probs:100.0|0.0 winner:Trump
# New York pct(trump|harris):37.4|52.6 probs:0.0|100.0 winner:Harris
# Wisconsin pct(trump|harris):46.0|49.0 probs:19.1|80.9 winner:Harris
# Kansas pct(trump|harris):52.0|41.0 probs:99.9|0.1 winner:Trump
# North Carolina pct(trump|harris):44.0|45.0 probs:37.8|62.2 winner:Harris
# Wyoming pct(trump|harris):52.6|20.2 probs:100.0|0.0 winner:Trump

# %%
votes_a, votes_b
# Out:
# (293, 242)

# %%
len(results)
# Out:
# 50

# %%
trump_counter = 0
harris_counter = 0
tie_counter = 0
results_results = []
for i in range(1000):
    results, votes_a, votes_b = simulate_election_with_probability(parsed_list, df, verbose=False)
    if votes_a > votes_b:
        winner = "Trump"
        trump_counter +=1
    elif votes_a < votes_b:
        winner = "Harris"
        harris_counter +=1
    else:
        winner="Tie!"
        tie_counter += 1
    print(f"Simulation #{i} winner:{winner} ")
    results_results.append(results)
    
print(f"TOTAL: trump: {trump_counter} harris:{harris_counter} tie:{tie_counter}")
# Out:
# Simulation #0 winner:Harris
# Simulation #1 winner:Trump
# Simulation #2 winner:Trump
# Simulation #3 winner:Trump
# Simulation #4 winner:Trump
# Simulation #5 winner:Harris
# Simulation #6 winner:Harris
# Simulation #7 winner:Trump
# Simulation #8 winner:Harris
# Simulation #9 winner:Harris
# Simulation #10 winner:Harris
# Simulation #11 winner:Trump
# Simulation #12 winner:Trump
# Simulation #13 winner:Trump
# Simulation #14 winner:Harris
# Simulation #15 winner:Trump
# Simulation #16 winner:Trump
# Simulation #17 winner:Harris
# Simulation #18 winner:Harris
# Simulation #19 winner:Harris
# Simulation #20 winner:Trump
# Simulation #21 winner:Harris
# Simulation #22 winner:Trump
# Simulation #23 winner:Trump
# Simulation #24 winner:Trump
# Simulation #25 winner:Harris
# Simulation #26 winner:Harris
# Simulation #27 winner:Harris
# Simulation #28 winner:Harris
# Simulation #29 winner:Trump
# Simulation #30 winner:Trump
# Simulation #31 winner:Trump
# Simulation #32 winner:Trump
# Simulation #33 winner:Trump
# Simulation #34 winner:Harris
# Simulation #35 winner:Harris
# Simulation #36 winner:Trump
# Simulation #37 winner:Trump
# Simulation #38 winner:Harris
# Simulation #39 winner:Trump
# Simulation #40 winner:Trump
# Simulation #41 winner:Harris
# Simulation #42 winner:Trump
# Simulation #43 winner:Trump
# Simulation #44 winner:Trump
# Simulation #45 winner:Trump
# Simulation #46 winner:Trump
# Simulation #47 winner:Trump
# Simulation #48 winner:Trump
# Simulation #49 winner:Harris
# Simulation #50 winner:Harris
# Simulation #51 winner:Trump
# Simulation #52 winner:Harris
# Simulation #53 winner:Trump
# Simulation #54 winner:Trump
# Simulation #55 winner:Harris
# Simulation #56 winner:Trump
# Simulation #57 winner:Harris
# Simulation #58 winner:Trump
# Simulation #59 winner:Harris
# Simulation #60 winner:Trump
# Simulation #61 winner:Harris
# Simulation #62 winner:Trump
# Simulation #63 winner:Trump
# Simulation #64 winner:Trump
# Simulation #65 winner:Trump
# Simulation #66 winner:Trump
# Simulation #67 winner:Trump
# Simulation #68 winner:Trump
# Simulation #69 winner:Trump
# Simulation #70 winner:Trump
# Simulation #71 winner:Harris
# Simulation #72 winner:Harris
# Simulation #73 winner:Trump
# Simulation #74 winner:Harris
# Simulation #75 winner:Trump
# Simulation #76 winner:Trump
# Simulation #77 winner:Trump
# Simulation #78 winner:Harris
# Simulation #79 winner:Trump
# Simulation #80 winner:Trump
# Simulation #81 winner:Trump
# Simulation #82 winner:Harris
# Simulation #83 winner:Trump
# Simulation #84 winner:Harris
# Simulation #85 winner:Trump
# Simulation #86 winner:Trump
# Simulation #87 winner:Trump
# Simulation #88 winner:Harris
# Simulation #89 winner:Trump
# Simulation #90 winner:Trump
# Simulation #91 winner:Trump
# Simulation #92 winner:Trump
# Simulation #93 winner:Harris
# Simulation #94 winner:Harris
# Simulation #95 winner:Trump
# Simulation #96 winner:Trump
# Simulation #97 winner:Harris
# Simulation #98 winner:Trump
# Simulation #99 winner:Trump
# Simulation #100 winner:Trump
# Simulation #101 winner:Trump
# Simulation #102 winner:Trump
# Simulation #103 winner:Harris
# Simulation #104 winner:Harris
# Simulation #105 winner:Trump
# Simulation #106 winner:Harris
# Simulation #107 winner:Harris
# Simulation #108 winner:Trump
# Simulation #109 winner:Harris
# Simulation #110 winner:Harris
# Simulation #111 winner:Harris
# Simulation #112 winner:Harris
# Simulation #113 winner:Trump
# Simulation #114 winner:Harris
# Simulation #115 winner:Trump
# Simulation #116 winner:Harris
# Simulation #117 winner:Harris
# Simulation #118 winner:Trump
# Simulation #119 winner:Trump
# Simulation #120 winner:Harris
# Simulation #121 winner:Trump
# Simulation #122 winner:Trump
# Simulation #123 winner:Trump
# Simulation #124 winner:Trump
# Simulation #125 winner:Harris
# Simulation #126 winner:Trump
# Simulation #127 winner:Harris
# Simulation #128 winner:Trump
# Simulation #129 winner:Trump
# Simulation #130 winner:Trump
# Simulation #131 winner:Trump
# Simulation #132 winner:Trump
# Simulation #133 winner:Trump
# Simulation #134 winner:Trump
# Simulation #135 winner:Trump
# Simulation #136 winner:Trump
# Simulation #137 winner:Harris
# Simulation #138 winner:Harris
# Simulation #139 winner:Trump
# Simulation #140 winner:Harris
# Simulation #141 winner:Trump
# Simulation #142 winner:Harris
# Simulation #143 winner:Trump
# Simulation #144 winner:Harris
# Simulation #145 winner:Harris
# Simulation #146 winner:Harris
# Simulation #147 winner:Trump
# Simulation #148 winner:Trump
# Simulation #149 winner:Harris
# Simulation #150 winner:Trump
# Simulation #151 winner:Harris
# Simulation #152 winner:Trump
# Simulation #153 winner:Trump
# Simulation #154 winner:Trump
# Simulation #155 winner:Trump
# Simulation #156 winner:Trump
# Simulation #157 winner:Trump
# Simulation #158 winner:Harris
# Simulation #159 winner:Harris
# Simulation #160 winner:Harris
# Simulation #161 winner:Trump
# Simulation #162 winner:Trump
# Simulation #163 winner:Trump
# Simulation #164 winner:Trump
# Simulation #165 winner:Harris
# Simulation #166 winner:Harris
# Simulation #167 winner:Trump
# Simulation #168 winner:Trump
# Simulation #169 winner:Harris
# Simulation #170 winner:Trump
# Simulation #171 winner:Trump
# Simulation #172 winner:Harris
# Simulation #173 winner:Trump
# Simulation #174 winner:Harris
# Simulation #175 winner:Trump
# Simulation #176 winner:Trump
# Simulation #177 winner:Trump
# Simulation #178 winner:Harris
# Simulation #179 winner:Trump
# Simulation #180 winner:Trump
# Simulation #181 winner:Harris
# Simulation #182 winner:Trump
# Simulation #183 winner:Trump
# Simulation #184 winner:Trump
# Simulation #185 winner:Trump
# Simulation #186 winner:Harris
# Simulation #187 winner:Trump
# Simulation #188 winner:Trump
# Simulation #189 winner:Harris
# Simulation #190 winner:Trump
# Simulation #191 winner:Harris
# Simulation #192 winner:Trump
# Simulation #193 winner:Trump
# Simulation #194 winner:Harris
# Simulation #195 winner:Trump
# Simulation #196 winner:Trump
# Simulation #197 winner:Trump
# Simulation #198 winner:Harris
# Simulation #199 winner:Trump
# Simulation #200 winner:Trump
# Simulation #201 winner:Trump
# Simulation #202 winner:Harris
# Simulation #203 winner:Harris
# Simulation #204 winner:Harris
# Simulation #205 winner:Harris
# Simulation #206 winner:Trump
# Simulation #207 winner:Trump
# Simulation #208 winner:Harris
# Simulation #209 winner:Trump
# Simulation #210 winner:Harris
# Simulation #211 winner:Harris
# Simulation #212 winner:Harris
# Simulation #213 winner:Harris
# Simulation #214 winner:Trump
# Simulation #215 winner:Trump
# Simulation #216 winner:Trump
# Simulation #217 winner:Harris
# Simulation #218 winner:Trump
# Simulation #219 winner:Trump
# Simulation #220 winner:Harris
# Simulation #221 winner:Trump
# Simulation #222 winner:Harris
# Simulation #223 winner:Trump
# Simulation #224 winner:Trump
# Simulation #225 winner:Trump
# Simulation #226 winner:Trump
# Simulation #227 winner:Harris
# Simulation #228 winner:Harris
# Simulation #229 winner:Trump
# Simulation #230 winner:Harris
# Simulation #231 winner:Trump
# Simulation #232 winner:Trump
# Simulation #233 winner:Trump
# Simulation #234 winner:Trump
# Simulation #235 winner:Harris
# Simulation #236 winner:Harris
# Simulation #237 winner:Harris
# Simulation #238 winner:Trump
# Simulation #239 winner:Trump
# Simulation #240 winner:Harris
# Simulation #241 winner:Trump
# Simulation #242 winner:Trump
# Simulation #243 winner:Harris
# Simulation #244 winner:Harris
# Simulation #245 winner:Harris
# Simulation #246 winner:Harris
# Simulation #247 winner:Harris
# Simulation #248 winner:Trump
# Simulation #249 winner:Harris
# Simulation #250 winner:Trump
# Simulation #251 winner:Trump
# Simulation #252 winner:Trump
# Simulation #253 winner:Harris
# Simulation #254 winner:Trump
# Simulation #255 winner:Trump
# Simulation #256 winner:Trump
# Simulation #257 winner:Trump
# Simulation #258 winner:Trump
# Simulation #259 winner:Trump
# Simulation #260 winner:Trump
# Simulation #261 winner:Harris
# Simulation #262 winner:Trump
# Simulation #263 winner:Harris
# Simulation #264 winner:Harris
# Simulation #265 winner:Harris
# Simulation #266 winner:Harris
# Simulation #267 winner:Trump
# Simulation #268 winner:Trump
# Simulation #269 winner:Trump
# Simulation #270 winner:Trump
# Simulation #271 winner:Trump
# Simulation #272 winner:Trump
# Simulation #273 winner:Trump
# Simulation #274 winner:Trump
# Simulation #275 winner:Trump
# Simulation #276 winner:Trump
# Simulation #277 winner:Trump
# Simulation #278 winner:Trump
# Simulation #279 winner:Harris
# Simulation #280 winner:Trump
# Simulation #281 winner:Trump
# Simulation #282 winner:Trump
# Simulation #283 winner:Trump
# Simulation #284 winner:Trump
# Simulation #285 winner:Trump
# Simulation #286 winner:Harris
# Simulation #287 winner:Harris
# Simulation #288 winner:Trump
# Simulation #289 winner:Trump
# Simulation #290 winner:Trump
# Simulation #291 winner:Harris
# Simulation #292 winner:Harris
# Simulation #293 winner:Trump
# Simulation #294 winner:Harris
# Simulation #295 winner:Trump
# Simulation #296 winner:Harris
# Simulation #297 winner:Trump
# Simulation #298 winner:Harris
# Simulation #299 winner:Harris
# Simulation #300 winner:Trump
# Simulation #301 winner:Harris
# Simulation #302 winner:Trump
# Simulation #303 winner:Trump
# Simulation #304 winner:Harris
# Simulation #305 winner:Harris
# Simulation #306 winner:Harris
# Simulation #307 winner:Trump
# Simulation #308 winner:Harris
# Simulation #309 winner:Trump
# Simulation #310 winner:Trump
# Simulation #311 winner:Trump
# Simulation #312 winner:Trump
# Simulation #313 winner:Trump
# Simulation #314 winner:Harris
# Simulation #315 winner:Trump
# Simulation #316 winner:Trump
# Simulation #317 winner:Trump
# Simulation #318 winner:Harris
# Simulation #319 winner:Trump
# Simulation #320 winner:Trump
# Simulation #321 winner:Trump
# Simulation #322 winner:Trump
# Simulation #323 winner:Trump
# Simulation #324 winner:Trump
# Simulation #325 winner:Trump
# Simulation #326 winner:Harris
# Simulation #327 winner:Trump
# Simulation #328 winner:Trump
# Simulation #329 winner:Trump
# Simulation #330 winner:Trump
# Simulation #331 winner:Trump
# Simulation #332 winner:Harris
# Simulation #333 winner:Trump
# Simulation #334 winner:Trump
# Simulation #335 winner:Harris
# Simulation #336 winner:Harris
# Simulation #337 winner:Trump
# Simulation #338 winner:Trump
# Simulation #339 winner:Trump
# Simulation #340 winner:Harris
# Simulation #341 winner:Trump
# Simulation #342 winner:Trump
# Simulation #343 winner:Trump
# Simulation #344 winner:Trump
# Simulation #345 winner:Trump
# Simulation #346 winner:Harris
# Simulation #347 winner:Trump
# Simulation #348 winner:Trump
# Simulation #349 winner:Trump
# Simulation #350 winner:Trump
# Simulation #351 winner:Trump
# Simulation #352 winner:Trump
# Simulation #353 winner:Trump
# Simulation #354 winner:Trump
# Simulation #355 winner:Harris
# Simulation #356 winner:Trump
# Simulation #357 winner:Harris
# Simulation #358 winner:Trump
# Simulation #359 winner:Harris
# Simulation #360 winner:Trump
# Simulation #361 winner:Trump
# Simulation #362 winner:Trump
# Simulation #363 winner:Harris
# Simulation #364 winner:Trump
# Simulation #365 winner:Trump
# Simulation #366 winner:Trump
# Simulation #367 winner:Trump
# Simulation #368 winner:Trump
# Simulation #369 winner:Harris
# Simulation #370 winner:Harris
# Simulation #371 winner:Harris
# Simulation #372 winner:Harris
# Simulation #373 winner:Trump
# Simulation #374 winner:Trump
# Simulation #375 winner:Trump
# Simulation #376 winner:Harris
# Simulation #377 winner:Trump
# Simulation #378 winner:Harris
# Simulation #379 winner:Harris
# Simulation #380 winner:Trump
# Simulation #381 winner:Harris
# Simulation #382 winner:Harris
# Simulation #383 winner:Trump
# Simulation #384 winner:Trump
# Simulation #385 winner:Trump
# Simulation #386 winner:Harris
# Simulation #387 winner:Trump
# Simulation #388 winner:Trump
# Simulation #389 winner:Trump
# Simulation #390 winner:Harris
# Simulation #391 winner:Harris
# Simulation #392 winner:Trump
# Simulation #393 winner:Harris
# Simulation #394 winner:Trump
# Simulation #395 winner:Trump
# Simulation #396 winner:Trump
# Simulation #397 winner:Trump
# Simulation #398 winner:Trump
# Simulation #399 winner:Harris
# Simulation #400 winner:Trump
# Simulation #401 winner:Harris
# Simulation #402 winner:Harris
# Simulation #403 winner:Trump
# Simulation #404 winner:Harris
# Simulation #405 winner:Harris
# Simulation #406 winner:Trump
# Simulation #407 winner:Harris
# Simulation #408 winner:Harris
# Simulation #409 winner:Trump
# Simulation #410 winner:Trump
# Simulation #411 winner:Harris
# Simulation #412 winner:Trump
# Simulation #413 winner:Trump
# Simulation #414 winner:Harris
# Simulation #415 winner:Trump
# Simulation #416 winner:Trump
# Simulation #417 winner:Trump
# Simulation #418 winner:Trump
# Simulation #419 winner:Trump
# Simulation #420 winner:Trump
# Simulation #421 winner:Trump
# Simulation #422 winner:Harris
# Simulation #423 winner:Trump
# Simulation #424 winner:Trump
# Simulation #425 winner:Harris
# Simulation #426 winner:Harris
# Simulation #427 winner:Trump
# Simulation #428 winner:Trump
# Simulation #429 winner:Trump
# Simulation #430 winner:Trump
# Simulation #431 winner:Trump
# Simulation #432 winner:Harris
# Simulation #433 winner:Harris
# Simulation #434 winner:Trump
# Simulation #435 winner:Trump
# Simulation #436 winner:Trump
# Simulation #437 winner:Trump
# Simulation #438 winner:Trump
# Simulation #439 winner:Trump
# Simulation #440 winner:Trump
# Simulation #441 winner:Harris
# Simulation #442 winner:Trump
# Simulation #443 winner:Harris
# Simulation #444 winner:Harris
# Simulation #445 winner:Harris
# Simulation #446 winner:Trump
# Simulation #447 winner:Harris
# Simulation #448 winner:Trump
# Simulation #449 winner:Harris
# Simulation #450 winner:Trump
# Simulation #451 winner:Trump
# Simulation #452 winner:Trump
# Simulation #453 winner:Trump
# Simulation #454 winner:Trump
# Simulation #455 winner:Trump
# Simulation #456 winner:Harris
# Simulation #457 winner:Trump
# Simulation #458 winner:Harris
# Simulation #459 winner:Trump
# Simulation #460 winner:Trump
# Simulation #461 winner:Harris
# Simulation #462 winner:Harris
# Simulation #463 winner:Trump
# Simulation #464 winner:Harris
# Simulation #465 winner:Harris
# Simulation #466 winner:Harris
# Simulation #467 winner:Trump
# Simulation #468 winner:Trump
# Simulation #469 winner:Trump
# Simulation #470 winner:Trump
# Simulation #471 winner:Harris
# Simulation #472 winner:Trump
# Simulation #473 winner:Harris
# Simulation #474 winner:Trump
# Simulation #475 winner:Trump
# Simulation #476 winner:Trump
# Simulation #477 winner:Harris
# Simulation #478 winner:Trump
# Simulation #479 winner:Trump
# Simulation #480 winner:Trump
# Simulation #481 winner:Trump
# Simulation #482 winner:Trump
# Simulation #483 winner:Trump
# Simulation #484 winner:Trump
# Simulation #485 winner:Trump
# Simulation #486 winner:Trump
# Simulation #487 winner:Trump
# Simulation #488 winner:Trump
# Simulation #489 winner:Trump
# Simulation #490 winner:Harris
# Simulation #491 winner:Trump
# Simulation #492 winner:Trump
# Simulation #493 winner:Trump
# Simulation #494 winner:Harris
# Simulation #495 winner:Trump
# Simulation #496 winner:Harris
# Simulation #497 winner:Trump
# Simulation #498 winner:Harris
# Simulation #499 winner:Harris
# Simulation #500 winner:Harris
# Simulation #501 winner:Harris
# Simulation #502 winner:Trump
# Simulation #503 winner:Trump
# Simulation #504 winner:Harris
# Simulation #505 winner:Trump
# Simulation #506 winner:Trump
# Simulation #507 winner:Trump
# Simulation #508 winner:Trump
# Simulation #509 winner:Trump
# Simulation #510 winner:Trump
# Simulation #511 winner:Trump
# Simulation #512 winner:Harris
# Simulation #513 winner:Harris
# Simulation #514 winner:Trump
# Simulation #515 winner:Harris
# Simulation #516 winner:Harris
# Simulation #517 winner:Trump
# Simulation #518 winner:Harris
# Simulation #519 winner:Trump
# Simulation #520 winner:Trump
# Simulation #521 winner:Trump
# Simulation #522 winner:Trump
# Simulation #523 winner:Trump
# Simulation #524 winner:Harris
# Simulation #525 winner:Trump
# Simulation #526 winner:Trump
# Simulation #527 winner:Trump
# Simulation #528 winner:Harris
# Simulation #529 winner:Trump
# Simulation #530 winner:Trump
# Simulation #531 winner:Trump
# Simulation #532 winner:Harris
# Simulation #533 winner:Harris
# Simulation #534 winner:Trump
# Simulation #535 winner:Trump
# Simulation #536 winner:Trump
# Simulation #537 winner:Trump
# Simulation #538 winner:Trump
# Simulation #539 winner:Trump
# Simulation #540 winner:Harris
# Simulation #541 winner:Trump
# Simulation #542 winner:Trump
# Simulation #543 winner:Trump
# Simulation #544 winner:Harris
# Simulation #545 winner:Harris
# Simulation #546 winner:Trump
# Simulation #547 winner:Trump
# Simulation #548 winner:Trump
# Simulation #549 winner:Trump
# Simulation #550 winner:Trump
# Simulation #551 winner:Trump
# Simulation #552 winner:Harris
# Simulation #553 winner:Harris
# Simulation #554 winner:Harris
# Simulation #555 winner:Trump
# Simulation #556 winner:Trump
# Simulation #557 winner:Harris
# Simulation #558 winner:Harris
# Simulation #559 winner:Trump
# Simulation #560 winner:Harris
# Simulation #561 winner:Trump
# Simulation #562 winner:Trump
# Simulation #563 winner:Trump
# Simulation #564 winner:Harris
# Simulation #565 winner:Trump
# Simulation #566 winner:Trump
# Simulation #567 winner:Harris
# Simulation #568 winner:Trump
# Simulation #569 winner:Trump
# Simulation #570 winner:Trump
# Simulation #571 winner:Trump
# Simulation #572 winner:Harris
# Simulation #573 winner:Harris
# Simulation #574 winner:Harris
# Simulation #575 winner:Trump
# Simulation #576 winner:Harris
# Simulation #577 winner:Harris
# Simulation #578 winner:Trump
# Simulation #579 winner:Trump
# Simulation #580 winner:Harris
# Simulation #581 winner:Harris
# Simulation #582 winner:Trump
# Simulation #583 winner:Trump
# Simulation #584 winner:Harris
# Simulation #585 winner:Trump
# Simulation #586 winner:Trump
# Simulation #587 winner:Trump
# Simulation #588 winner:Harris
# Simulation #589 winner:Trump
# Simulation #590 winner:Trump
# Simulation #591 winner:Harris
# Simulation #592 winner:Trump
# Simulation #593 winner:Harris
# Simulation #594 winner:Harris
# Simulation #595 winner:Harris
# Simulation #596 winner:Trump
# Simulation #597 winner:Trump
# Simulation #598 winner:Trump
# Simulation #599 winner:Harris
# Simulation #600 winner:Trump
# Simulation #601 winner:Harris
# Simulation #602 winner:Harris
# Simulation #603 winner:Harris
# Simulation #604 winner:Trump
# Simulation #605 winner:Harris
# Simulation #606 winner:Trump
# Simulation #607 winner:Trump
# Simulation #608 winner:Trump
# Simulation #609 winner:Harris
# Simulation #610 winner:Harris
# Simulation #611 winner:Trump
# Simulation #612 winner:Trump
# Simulation #613 winner:Trump
# Simulation #614 winner:Trump
# Simulation #615 winner:Trump
# Simulation #616 winner:Harris
# Simulation #617 winner:Trump
# Simulation #618 winner:Trump
# Simulation #619 winner:Trump
# Simulation #620 winner:Harris
# Simulation #621 winner:Harris
# Simulation #622 winner:Trump
# Simulation #623 winner:Harris
# Simulation #624 winner:Harris
# Simulation #625 winner:Trump
# Simulation #626 winner:Trump
# Simulation #627 winner:Trump
# Simulation #628 winner:Harris
# Simulation #629 winner:Trump
# Simulation #630 winner:Harris
# Simulation #631 winner:Harris
# Simulation #632 winner:Harris
# Simulation #633 winner:Harris
# Simulation #634 winner:Trump
# Simulation #635 winner:Trump
# Simulation #636 winner:Trump
# Simulation #637 winner:Trump
# Simulation #638 winner:Harris
# Simulation #639 winner:Trump
# Simulation #640 winner:Trump
# Simulation #641 winner:Trump
# Simulation #642 winner:Trump
# Simulation #643 winner:Trump
# Simulation #644 winner:Harris
# Simulation #645 winner:Trump
# Simulation #646 winner:Harris
# Simulation #647 winner:Trump
# Simulation #648 winner:Trump
# Simulation #649 winner:Trump
# Simulation #650 winner:Harris
# Simulation #651 winner:Trump
# Simulation #652 winner:Harris
# Simulation #653 winner:Trump
# Simulation #654 winner:Trump
# Simulation #655 winner:Trump
# Simulation #656 winner:Harris
# Simulation #657 winner:Trump
# Simulation #658 winner:Harris
# Simulation #659 winner:Trump
# Simulation #660 winner:Trump
# Simulation #661 winner:Trump
# Simulation #662 winner:Trump
# Simulation #663 winner:Harris
# Simulation #664 winner:Trump
# Simulation #665 winner:Trump
# Simulation #666 winner:Harris
# Simulation #667 winner:Harris
# Simulation #668 winner:Trump
# Simulation #669 winner:Trump
# Simulation #670 winner:Trump
# Simulation #671 winner:Harris
# Simulation #672 winner:Harris
# Simulation #673 winner:Trump
# Simulation #674 winner:Harris
# Simulation #675 winner:Harris
# Simulation #676 winner:Trump
# Simulation #677 winner:Trump
# Simulation #678 winner:Harris
# Simulation #679 winner:Trump
# Simulation #680 winner:Harris
# Simulation #681 winner:Harris
# Simulation #682 winner:Harris
# Simulation #683 winner:Harris
# Simulation #684 winner:Trump
# Simulation #685 winner:Trump
# Simulation #686 winner:Harris
# Simulation #687 winner:Trump
# Simulation #688 winner:Trump
# Simulation #689 winner:Harris
# Simulation #690 winner:Trump
# Simulation #691 winner:Trump
# Simulation #692 winner:Trump
# Simulation #693 winner:Trump
# Simulation #694 winner:Harris
# Simulation #695 winner:Trump
# Simulation #696 winner:Harris
# Simulation #697 winner:Trump
# Simulation #698 winner:Harris
# Simulation #699 winner:Harris
# Simulation #700 winner:Trump
# Simulation #701 winner:Trump
# Simulation #702 winner:Trump
# Simulation #703 winner:Trump
# Simulation #704 winner:Trump
# Simulation #705 winner:Harris
# Simulation #706 winner:Harris
# Simulation #707 winner:Trump
# Simulation #708 winner:Harris
# Simulation #709 winner:Harris
# Simulation #710 winner:Trump
# Simulation #711 winner:Trump
# Simulation #712 winner:Trump
# Simulation #713 winner:Harris
# Simulation #714 winner:Trump
# Simulation #715 winner:Trump
# Simulation #716 winner:Trump
# Simulation #717 winner:Trump
# Simulation #718 winner:Trump
# Simulation #719 winner:Trump
# Simulation #720 winner:Trump
# Simulation #721 winner:Trump
# Simulation #722 winner:Trump
# Simulation #723 winner:Harris
# Simulation #724 winner:Trump
# Simulation #725 winner:Trump
# Simulation #726 winner:Trump
# Simulation #727 winner:Trump
# Simulation #728 winner:Trump
# Simulation #729 winner:Trump
# Simulation #730 winner:Trump
# Simulation #731 winner:Trump
# Simulation #732 winner:Harris
# Simulation #733 winner:Trump
# Simulation #734 winner:Harris
# Simulation #735 winner:Harris
# Simulation #736 winner:Harris
# Simulation #737 winner:Trump
# Simulation #738 winner:Trump
# Simulation #739 winner:Trump
# Simulation #740 winner:Harris
# Simulation #741 winner:Trump
# Simulation #742 winner:Harris
# Simulation #743 winner:Trump
# Simulation #744 winner:Harris
# Simulation #745 winner:Harris
# Simulation #746 winner:Trump
# Simulation #747 winner:Harris
# Simulation #748 winner:Trump
# Simulation #749 winner:Trump
# Simulation #750 winner:Trump
# Simulation #751 winner:Trump
# Simulation #752 winner:Trump
# Simulation #753 winner:Trump
# Simulation #754 winner:Trump
# Simulation #755 winner:Trump
# Simulation #756 winner:Trump
# Simulation #757 winner:Trump
# Simulation #758 winner:Trump
# Simulation #759 winner:Harris
# Simulation #760 winner:Harris
# Simulation #761 winner:Trump
# Simulation #762 winner:Trump
# Simulation #763 winner:Harris
# Simulation #764 winner:Trump
# Simulation #765 winner:Trump
# Simulation #766 winner:Harris
# Simulation #767 winner:Trump
# Simulation #768 winner:Trump
# Simulation #769 winner:Harris
# Simulation #770 winner:Trump
# Simulation #771 winner:Harris
# Simulation #772 winner:Trump
# Simulation #773 winner:Harris
# Simulation #774 winner:Trump
# Simulation #775 winner:Trump
# Simulation #776 winner:Trump
# Simulation #777 winner:Harris
# Simulation #778 winner:Trump
# Simulation #779 winner:Trump
# Simulation #780 winner:Trump
# Simulation #781 winner:Trump
# Simulation #782 winner:Harris
# Simulation #783 winner:Trump
# Simulation #784 winner:Harris
# Simulation #785 winner:Trump
# Simulation #786 winner:Trump
# Simulation #787 winner:Trump
# Simulation #788 winner:Harris
# Simulation #789 winner:Trump
# Simulation #790 winner:Harris
# Simulation #791 winner:Trump
# Simulation #792 winner:Harris
# Simulation #793 winner:Trump
# Simulation #794 winner:Harris
# Simulation #795 winner:Trump
# Simulation #796 winner:Trump
# Simulation #797 winner:Harris
# Simulation #798 winner:Harris
# Simulation #799 winner:Harris
# Simulation #800 winner:Trump
# Simulation #801 winner:Trump
# Simulation #802 winner:Trump
# Simulation #803 winner:Trump
# Simulation #804 winner:Trump
# Simulation #805 winner:Harris
# Simulation #806 winner:Trump
# Simulation #807 winner:Trump
# Simulation #808 winner:Trump
# Simulation #809 winner:Harris
# Simulation #810 winner:Harris
# Simulation #811 winner:Trump
# Simulation #812 winner:Trump
# Simulation #813 winner:Trump
# Simulation #814 winner:Trump
# Simulation #815 winner:Harris
# Simulation #816 winner:Trump
# Simulation #817 winner:Harris
# Simulation #818 winner:Harris
# Simulation #819 winner:Trump
# Simulation #820 winner:Trump
# Simulation #821 winner:Trump
# Simulation #822 winner:Trump
# Simulation #823 winner:Harris
# Simulation #824 winner:Trump
# Simulation #825 winner:Trump
# Simulation #826 winner:Trump
# Simulation #827 winner:Harris
# Simulation #828 winner:Harris
# Simulation #829 winner:Trump
# Simulation #830 winner:Trump
# Simulation #831 winner:Trump
# Simulation #832 winner:Harris
# Simulation #833 winner:Trump
# Simulation #834 winner:Trump
# Simulation #835 winner:Harris
# Simulation #836 winner:Harris
# Simulation #837 winner:Trump
# Simulation #838 winner:Trump
# Simulation #839 winner:Harris
# Simulation #840 winner:Harris
# Simulation #841 winner:Trump
# Simulation #842 winner:Harris
# Simulation #843 winner:Trump
# Simulation #844 winner:Harris
# Simulation #845 winner:Harris
# Simulation #846 winner:Trump
# Simulation #847 winner:Trump
# Simulation #848 winner:Harris
# Simulation #849 winner:Harris
# Simulation #850 winner:Trump
# Simulation #851 winner:Harris
# Simulation #852 winner:Harris
# Simulation #853 winner:Trump
# Simulation #854 winner:Harris
# Simulation #855 winner:Trump
# Simulation #856 winner:Trump
# Simulation #857 winner:Harris
# Simulation #858 winner:Harris
# Simulation #859 winner:Harris
# Simulation #860 winner:Harris
# Simulation #861 winner:Trump
# Simulation #862 winner:Harris
# Simulation #863 winner:Trump
# Simulation #864 winner:Trump
# Simulation #865 winner:Trump
# Simulation #866 winner:Trump
# Simulation #867 winner:Harris
# Simulation #868 winner:Trump
# Simulation #869 winner:Trump
# Simulation #870 winner:Harris
# Simulation #871 winner:Harris
# Simulation #872 winner:Trump
# Simulation #873 winner:Trump
# Simulation #874 winner:Trump
# Simulation #875 winner:Harris
# Simulation #876 winner:Trump
# Simulation #877 winner:Trump
# Simulation #878 winner:Trump
# Simulation #879 winner:Trump
# Simulation #880 winner:Trump
# Simulation #881 winner:Trump
# Simulation #882 winner:Trump
# Simulation #883 winner:Harris
# Simulation #884 winner:Trump
# Simulation #885 winner:Harris
# Simulation #886 winner:Harris
# Simulation #887 winner:Harris
# Simulation #888 winner:Trump
# Simulation #889 winner:Harris
# Simulation #890 winner:Harris
# Simulation #891 winner:Trump
# Simulation #892 winner:Harris
# Simulation #893 winner:Harris
# Simulation #894 winner:Trump
# Simulation #895 winner:Trump
# Simulation #896 winner:Trump
# Simulation #897 winner:Trump
# Simulation #898 winner:Harris
# Simulation #899 winner:Harris
# Simulation #900 winner:Trump
# Simulation #901 winner:Trump
# Simulation #902 winner:Trump
# Simulation #903 winner:Harris
# Simulation #904 winner:Harris
# Simulation #905 winner:Trump
# Simulation #906 winner:Harris
# Simulation #907 winner:Harris
# Simulation #908 winner:Harris
# Simulation #909 winner:Harris
# Simulation #910 winner:Trump
# Simulation #911 winner:Trump
# Simulation #912 winner:Trump
# Simulation #913 winner:Harris
# Simulation #914 winner:Harris
# Simulation #915 winner:Trump
# Simulation #916 winner:Trump
# Simulation #917 winner:Harris
# Simulation #918 winner:Trump
# Simulation #919 winner:Harris
# Simulation #920 winner:Trump
# Simulation #921 winner:Trump
# Simulation #922 winner:Trump
# Simulation #923 winner:Trump
# Simulation #924 winner:Harris
# Simulation #925 winner:Trump
# Simulation #926 winner:Harris
# Simulation #927 winner:Trump
# Simulation #928 winner:Harris
# Simulation #929 winner:Harris
# Simulation #930 winner:Trump
# Simulation #931 winner:Trump
# Simulation #932 winner:Harris
# Simulation #933 winner:Trump
# Simulation #934 winner:Trump
# Simulation #935 winner:Trump
# Simulation #936 winner:Harris
# Simulation #937 winner:Trump
# Simulation #938 winner:Harris
# Simulation #939 winner:Trump
# Simulation #940 winner:Trump
# Simulation #941 winner:Harris
# Simulation #942 winner:Trump
# Simulation #943 winner:Trump
# Simulation #944 winner:Trump
# Simulation #945 winner:Harris
# Simulation #946 winner:Trump
# Simulation #947 winner:Harris
# Simulation #948 winner:Trump
# Simulation #949 winner:Trump
# Simulation #950 winner:Trump
# Simulation #951 winner:Trump
# Simulation #952 winner:Trump
# Simulation #953 winner:Trump
# Simulation #954 winner:Harris
# Simulation #955 winner:Harris
# Simulation #956 winner:Harris
# Simulation #957 winner:Harris
# Simulation #958 winner:Harris
# Simulation #959 winner:Trump
# Simulation #960 winner:Harris
# Simulation #961 winner:Harris
# Simulation #962 winner:Trump
# Simulation #963 winner:Harris
# Simulation #964 winner:Trump
# Simulation #965 winner:Trump
# Simulation #966 winner:Harris
# Simulation #967 winner:Harris
# Simulation #968 winner:Harris
# Simulation #969 winner:Trump
# Simulation #970 winner:Harris
# Simulation #971 winner:Trump
# Simulation #972 winner:Trump
# Simulation #973 winner:Trump
# Simulation #974 winner:Trump
# Simulation #975 winner:Trump
# Simulation #976 winner:Harris
# Simulation #977 winner:Trump
# Simulation #978 winner:Trump
# Simulation #979 winner:Trump
# Simulation #980 winner:Trump
# Simulation #981 winner:Trump
# Simulation #982 winner:Trump
# Simulation #983 winner:Trump
# Simulation #984 winner:Trump
# Simulation #985 winner:Harris
# Simulation #986 winner:Harris
# Simulation #987 winner:Trump
# Simulation #988 winner:Harris
# Simulation #989 winner:Harris
# Simulation #990 winner:Trump
# Simulation #991 winner:Trump
# Simulation #992 winner:Trump
# Simulation #993 winner:Trump
# Simulation #994 winner:Harris
# Simulation #995 winner:Trump
# Simulation #996 winner:Trump
# Simulation #997 winner:Harris
# Simulation #998 winner:Trump
# Simulation #999 winner:Trump
# TOTAL: trump: 631 harris:369 tie:0

# %%
filtered_results_results = []
for item in results_results:
    filt = {state: {'winner': data['winner'], 'votes': data['votes']} 
                    for state, data in item.items()}
    filtered_results_results.append(filt)

# %%
filtered_results_results[0:2]
# Out:
# [{'Alabama': {'winner': 'Trump', 'votes': 9},
#   'Kentucky': {'winner': 'Trump', 'votes': 8},
#   'North Dakota': {'winner': 'Trump', 'votes': 3},
#   'Alaska': {'winner': 'Trump', 'votes': 3},
#   'Louisiana': {'winner': 'Trump', 'votes': 8},
#   'Ohio': {'winner': 'Trump', 'votes': 17},
#   'Arizona': {'winner': 'Trump', 'votes': 11},
#   'Maine': {'winner': 'Harris', 'votes': 4},
#   'Oklahoma': {'winner': 'Trump', 'votes': 7},
#   'Arkansas': {'winner': 'Trump', 'votes': 6},
#   'Maryland': {'winner': 'Harris', 'votes': 10},
#   'Oregon': {'winner': 'Harris', 'votes': 8},
#   'California': {'winner': 'Harris', 'votes': 54},
#   'Massachusetts': {'winner': 'Harris', 'votes': 11},
#   'Pennsylvania': {'winner': 'Harris', 'votes': 19},
#   'Colorado': {'winner': 'Harris', 'votes': 10},
#   'Michigan': {'winner': 'Harris', 'votes': 15},
#   'Rhode Island': {'winner': 'Harris', 'votes': 4},
#   'Connecticut': {'winner': 'Harris', 'votes': 7},
#   'Minnesota': {'winner': 'Harris', 'votes': 10},
#   'South Carolina': {'winner': 'Trump', 'votes': 9},
#   'Delaware': {'winner': 'Harris', 'votes': 3},
#   'Mississippi': {'winner': 'Trump', 'votes': 6},
#   'South Dakota': {'winner': 'Trump', 'votes': 3},
#   'Missouri': {'winner': 'Trump', 'votes': 10},
#   'Tennessee': {'winner': 'Trump', 'votes': 11},
#   'Florida': {'winner': 'Trump', 'votes': 30},
#   'Montana': {'winner': 'Trump', 'votes': 4},
#   'Texas': {'winner': 'Trump', 'votes': 40},
#   'Georgia': {'winner': 'Trump', 'votes': 16},
#   'Nebraska': {'winner': 'Trump', 'votes': 5},
#   'Utah': {'winner': 'Trump', 'votes': 6},
#   'Hawaii': {'winner': 'Harris', 'votes': 4},
#   'Nevada': {'winner': 'Trump', 'votes': 6},
#   'Vermont': {'winner': 'Harris', 'votes': 3},
#   'Idaho': {'winner': 'Trump', 'votes': 4},
#   'New Hampshire': {'winner': 'Harris', 'votes': 4},
#   'Virginia': {'winner': 'Harris', 'votes': 13},
#   'Illinois': {'winner': 'Harris', 'votes': 19},
#   'New Jersey': {'winner': 'Harris', 'votes': 14},
#   'Washington': {'winner': 'Harris', 'votes': 12},
#   'Indiana': {'winner': 'Trump', 'votes': 11},
#   'New Mexico': {'winner': 'Harris', 'votes': 5},
#   'West Virginia': {'winner': 'Trump', 'votes': 4},
#   'Iowa': {'winner': 'Trump', 'votes': 6},
#   'New York': {'winner': 'Harris', 'votes': 28},
#   'Wisconsin': {'winner': 'Harris', 'votes': 10},
#   'Kansas': {'winner': 'Trump', 'votes': 6},
#   'North Carolina': {'winner': 'Harris', 'votes': 16},
#   'Wyoming': {'winner': 'Trump', 'votes': 3}},
#  {'Alabama': {'winner': 'Trump', 'votes': 9},
#   'Kentucky': {'winner': 'Trump', 'votes': 8},
#   'North Dakota': {'winner': 'Trump', 'votes': 3},
#   'Alaska': {'winner': 'Trump', 'votes': 3},
#   'Louisiana': {'winner': 'Trump', 'votes': 8},
#   'Ohio': {'winner': 'Trump', 'votes': 17},
#   'Arizona': {'winner': 'Trump', 'votes': 11},
#   'Maine': {'winner': 'Harris', 'votes': 4},
#   'Oklahoma': {'winner': 'Trump', 'votes': 7},
#   'Arkansas': {'winner': 'Trump', 'votes': 6},
#   'Maryland': {'winner': 'Harris', 'votes': 10},
#   'Oregon': {'winner': 'Harris', 'votes': 8},
#   'California': {'winner': 'Harris', 'votes': 54},
#   'Massachusetts': {'winner': 'Harris', 'votes': 11},
#   'Pennsylvania': {'winner': 'Trump', 'votes': 19},
#   'Colorado': {'winner': 'Harris', 'votes': 10},
#   'Michigan': {'winner': 'Harris', 'votes': 15},
#   'Rhode Island': {'winner': 'Harris', 'votes': 4},
#   'Connecticut': {'winner': 'Harris', 'votes': 7},
#   'Minnesota': {'winner': 'Harris', 'votes': 10},
#   'South Carolina': {'winner': 'Trump', 'votes': 9},
#   'Delaware': {'winner': 'Harris', 'votes': 3},
#   'Mississippi': {'winner': 'Trump', 'votes': 6},
#   'South Dakota': {'winner': 'Trump', 'votes': 3},
#   'Missouri': {'winner': 'Trump', 'votes': 10},
#   'Tennessee': {'winner': 'Trump', 'votes': 11},
#   'Florida': {'winner': 'Trump', 'votes': 30},
#   'Montana': {'winner': 'Trump', 'votes': 4},
#   'Texas': {'winner': 'Trump', 'votes': 40},
#   'Georgia': {'winner': 'Trump', 'votes': 16},
#   'Nebraska': {'winner': 'Trump', 'votes': 5},
#   'Utah': {'winner': 'Trump', 'votes': 6},
#   'Hawaii': {'winner': 'Harris', 'votes': 4},
#   'Nevada': {'winner': 'Trump', 'votes': 6},
#   'Vermont': {'winner': 'Harris', 'votes': 3},
#   'Idaho': {'winner': 'Trump', 'votes': 4},
#   'New Hampshire': {'winner': 'Harris', 'votes': 4},
#   'Virginia': {'winner': 'Harris', 'votes': 13},
#   'Illinois': {'winner': 'Harris', 'votes': 19},
#   'New Jersey': {'winner': 'Trump', 'votes': 14},
#   'Washington': {'winner': 'Harris', 'votes': 12},
#   'Indiana': {'winner': 'Trump', 'votes': 11},
#   'New Mexico': {'winner': 'Harris', 'votes': 5},
#   'West Virginia': {'winner': 'Trump', 'votes': 4},
#   'Iowa': {'winner': 'Trump', 'votes': 6},
#   'New York': {'winner': 'Harris', 'votes': 28},
#   'Wisconsin': {'winner': 'Harris', 'votes': 10},
#   'Kansas': {'winner': 'Trump', 'votes': 6},
#   'North Carolina': {'winner': 'Trump', 'votes': 16},
#   'Wyoming': {'winner': 'Trump', 'votes': 3}}]

# %%
from collections import Counter
import json

def dict_to_tuple(d):
    return tuple(sorted((k, dict_to_tuple(v) if isinstance(v, dict) else v) for k, v in d.items()))

# Convert each dictionary to a tuple of items
tuple_list = [dict_to_tuple(d) for d in filtered_results_results]

# Count the occurrences of each unique combination
combination_counts = Counter(tuple_list)

# Format the results as requested
formatted_results = [
    {
        "combination": json.loads(json.dumps(dict(combo))),
        "frequency": count
    }
    for combo, count in combination_counts.items()
]

# Print the results
# for result in formatted_results:
#     print(f"Combination: {result['combination']}")
#     print(f"Frequency: {result['frequency']}")
#     print()

# %%
formatted_results.sort(key=lambda x: x['frequency'], reverse=True)

# %%
formatted_results[0]
# Out:
# {'combination': {'Alabama': [['votes', 9], ['winner', 'Trump']],
#   'Alaska': [['votes', 3], ['winner', 'Trump']],
#   'Arizona': [['votes', 11], ['winner', 'Harris']],
#   'Arkansas': [['votes', 6], ['winner', 'Trump']],
#   'California': [['votes', 54], ['winner', 'Harris']],
#   'Colorado': [['votes', 10], ['winner', 'Harris']],
#   'Connecticut': [['votes', 7], ['winner', 'Harris']],
#   'Delaware': [['votes', 3], ['winner', 'Harris']],
#   'Florida': [['votes', 30], ['winner', 'Trump']],
#   'Georgia': [['votes', 16], ['winner', 'Trump']],
#   'Hawaii': [['votes', 4], ['winner', 'Harris']],
#   'Idaho': [['votes', 4], ['winner', 'Trump']],
#   'Illinois': [['votes', 19], ['winner', 'Harris']],
#   'Indiana': [['votes', 11], ['winner', 'Trump']],
#   'Iowa': [['votes', 6], ['winner', 'Trump']],
#   'Kansas': [['votes', 6], ['winner', 'Trump']],
#   'Kentucky': [['votes', 8], ['winner', 'Trump']],
#   'Louisiana': [['votes', 8], ['winner', 'Trump']],
#   'Maine': [['votes', 4], ['winner', 'Harris']],
#   'Maryland': [['votes', 10], ['winner', 'Harris']],
#   'Massachusetts': [['votes', 11], ['winner', 'Harris']],
#   'Michigan': [['votes', 15], ['winner', 'Harris']],
#   'Minnesota': [['votes', 10], ['winner', 'Harris']],
#   'Mississippi': [['votes', 6], ['winner', 'Trump']],
#   'Missouri': [['votes', 10], ['winner', 'Trump']],
#   'Montana': [['votes', 4], ['winner', 'Trump']],
#   'Nebraska': [['votes', 5], ['winner', 'Trump']],
#   'Nevada': [['votes', 6], ['winner', 'Trump']],
#   'New Hampshire': [['votes', 4], ['winner', 'Harris']],
#   'New Jersey': [['votes', 14], ['winner', 'Trump']],
#   'New Mexico': [['votes', 5], ['winner', 'Harris']],
#   'New York': [['votes', 28], ['winner', 'Harris']],
#   'North Carolina': [['votes', 16], ['winner', 'Harris']],
#   'North Dakota': [['votes', 3], ['winner', 'Trump']],
#   'Ohio': [['votes', 17], ['winner', 'Trump']],
#   'Oklahoma': [['votes', 7], ['winner', 'Trump']],
#   'Oregon': [['votes', 8], ['winner', 'Harris']],
#   'Pennsylvania': [['votes', 19], ['winner', 'Trump']],
#   'Rhode Island': [['votes', 4], ['winner', 'Harris']],
#   'South Carolina': [['votes', 9], ['winner', 'Trump']],
#   'South Dakota': [['votes', 3], ['winner', 'Trump']],
#   'Tennessee': [['votes', 11], ['winner', 'Trump']],
#   'Texas': [['votes', 40], ['winner', 'Trump']],
#   'Utah': [['votes', 6], ['winner', 'Trump']],
#   'Vermont': [['votes', 3], ['winner', 'Harris']],
#   'Virginia': [['votes', 13], ['winner', 'Harris']],
#   'Washington': [['votes', 12], ['winner', 'Harris']],
#   'West Virginia': [['votes', 4], ['winner', 'Trump']],
#   'Wisconsin': [['votes', 10], ['winner', 'Harris']],
#   'Wyoming': [['votes', 3], ['winner', 'Trump']]},
#  'frequency': 17}

# %%
def convert_results(results_list):
    new_results = []
    
    for result in results_list:
        trump_votes = 0
        harris_votes = 0
        
        for state_data in result.values():
            if state_data['winner'] == 'Trump':
                trump_votes += state_data['votes']
            elif state_data['winner'] == 'Harris':
                harris_votes += state_data['votes']
        
        new_result = {
            "result_details": result,
            "trump_votes": trump_votes,
            "harris_votes": harris_votes
        }
        
        new_results.append(new_result)
    
    return new_results

# %%
results_with_votes = convert_results(filtered_results_results)

# %%
results_with_votes[0]
# Out:
# {'result_details': {'Alabama': {'winner': 'Trump', 'votes': 9},
#   'Kentucky': {'winner': 'Trump', 'votes': 8},
#   'North Dakota': {'winner': 'Trump', 'votes': 3},
#   'Alaska': {'winner': 'Trump', 'votes': 3},
#   'Louisiana': {'winner': 'Trump', 'votes': 8},
#   'Ohio': {'winner': 'Trump', 'votes': 17},
#   'Arizona': {'winner': 'Trump', 'votes': 11},
#   'Maine': {'winner': 'Harris', 'votes': 4},
#   'Oklahoma': {'winner': 'Trump', 'votes': 7},
#   'Arkansas': {'winner': 'Trump', 'votes': 6},
#   'Maryland': {'winner': 'Harris', 'votes': 10},
#   'Oregon': {'winner': 'Harris', 'votes': 8},
#   'California': {'winner': 'Harris', 'votes': 54},
#   'Massachusetts': {'winner': 'Harris', 'votes': 11},
#   'Pennsylvania': {'winner': 'Harris', 'votes': 19},
#   'Colorado': {'winner': 'Harris', 'votes': 10},
#   'Michigan': {'winner': 'Harris', 'votes': 15},
#   'Rhode Island': {'winner': 'Harris', 'votes': 4},
#   'Connecticut': {'winner': 'Harris', 'votes': 7},
#   'Minnesota': {'winner': 'Harris', 'votes': 10},
#   'South Carolina': {'winner': 'Trump', 'votes': 9},
#   'Delaware': {'winner': 'Harris', 'votes': 3},
#   'Mississippi': {'winner': 'Trump', 'votes': 6},
#   'South Dakota': {'winner': 'Trump', 'votes': 3},
#   'Missouri': {'winner': 'Trump', 'votes': 10},
#   'Tennessee': {'winner': 'Trump', 'votes': 11},
#   'Florida': {'winner': 'Trump', 'votes': 30},
#   'Montana': {'winner': 'Trump', 'votes': 4},
#   'Texas': {'winner': 'Trump', 'votes': 40},
#   'Georgia': {'winner': 'Trump', 'votes': 16},
#   'Nebraska': {'winner': 'Trump', 'votes': 5},
#   'Utah': {'winner': 'Trump', 'votes': 6},
#   'Hawaii': {'winner': 'Harris', 'votes': 4},
#   'Nevada': {'winner': 'Trump', 'votes': 6},
#   'Vermont': {'winner': 'Harris', 'votes': 3},
#   'Idaho': {'winner': 'Trump', 'votes': 4},
#   'New Hampshire': {'winner': 'Harris', 'votes': 4},
#   'Virginia': {'winner': 'Harris', 'votes': 13},
#   'Illinois': {'winner': 'Harris', 'votes': 19},
#   'New Jersey': {'winner': 'Harris', 'votes': 14},
#   'Washington': {'winner': 'Harris', 'votes': 12},
#   'Indiana': {'winner': 'Trump', 'votes': 11},
#   'New Mexico': {'winner': 'Harris', 'votes': 5},
#   'West Virginia': {'winner': 'Trump', 'votes': 4},
#   'Iowa': {'winner': 'Trump', 'votes': 6},
#   'New York': {'winner': 'Harris', 'votes': 28},
#   'Wisconsin': {'winner': 'Harris', 'votes': 10},
#   'Kansas': {'winner': 'Trump', 'votes': 6},
#   'North Carolina': {'winner': 'Harris', 'votes': 16},
#   'Wyoming': {'winner': 'Trump', 'votes': 3}},
#  'trump_votes': 252,
#  'harris_votes': 283}

# %%
def dict_to_tuple(d):
    return tuple(sorted((k, dict_to_tuple(v) if isinstance(v, dict) else v) for k, v in d.items()))

# Convert each dictionary to a tuple of items
tuple_list = [dict_to_tuple(d) for d in results_with_votes]

# Count the occurrences of each unique combination
combination_counts = Counter(tuple_list)

# Format the results as requested
formatted_results = [
    {
        "combination": json.loads(json.dumps(dict(combo))),
        "frequency": count
    }
    for combo, count in combination_counts.items()
]

# %%
formatted_results.sort(key=lambda x: x['frequency'], reverse=True)
formatted_results[0]
# Out:
# {'combination': {'harris_votes': 261,
#   'result_details': [['Alabama', [['votes', 9], ['winner', 'Trump']]],
#    ['Alaska', [['votes', 3], ['winner', 'Trump']]],
#    ['Arizona', [['votes', 11], ['winner', 'Harris']]],
#    ['Arkansas', [['votes', 6], ['winner', 'Trump']]],
#    ['California', [['votes', 54], ['winner', 'Harris']]],
#    ['Colorado', [['votes', 10], ['winner', 'Harris']]],
#    ['Connecticut', [['votes', 7], ['winner', 'Harris']]],
#    ['Delaware', [['votes', 3], ['winner', 'Harris']]],
#    ['Florida', [['votes', 30], ['winner', 'Trump']]],
#    ['Georgia', [['votes', 16], ['winner', 'Trump']]],
#    ['Hawaii', [['votes', 4], ['winner', 'Harris']]],
#    ['Idaho', [['votes', 4], ['winner', 'Trump']]],
#    ['Illinois', [['votes', 19], ['winner', 'Harris']]],
#    ['Indiana', [['votes', 11], ['winner', 'Trump']]],
#    ['Iowa', [['votes', 6], ['winner', 'Trump']]],
#    ['Kansas', [['votes', 6], ['winner', 'Trump']]],
#    ['Kentucky', [['votes', 8], ['winner', 'Trump']]],
#    ['Louisiana', [['votes', 8], ['winner', 'Trump']]],
#    ['Maine', [['votes', 4], ['winner', 'Harris']]],
#    ['Maryland', [['votes', 10], ['winner', 'Harris']]],
#    ['Massachusetts', [['votes', 11], ['winner', 'Harris']]],
#    ['Michigan', [['votes', 15], ['winner', 'Harris']]],
#    ['Minnesota', [['votes', 10], ['winner', 'Harris']]],
#    ['Mississippi', [['votes', 6], ['winner', 'Trump']]],
#    ['Missouri', [['votes', 10], ['winner', 'Trump']]],
#    ['Montana', [['votes', 4], ['winner', 'Trump']]],
#    ['Nebraska', [['votes', 5], ['winner', 'Trump']]],
#    ['Nevada', [['votes', 6], ['winner', 'Trump']]],
#    ['New Hampshire', [['votes', 4], ['winner', 'Harris']]],
#    ['New Jersey', [['votes', 14], ['winner', 'Trump']]],
#    ['New Mexico', [['votes', 5], ['winner', 'Harris']]],
#    ['New York', [['votes', 28], ['winner', 'Harris']]],
#    ['North Carolina', [['votes', 16], ['winner', 'Harris']]],
#    ['North Dakota', [['votes', 3], ['winner', 'Trump']]],
#    ['Ohio', [['votes', 17], ['winner', 'Trump']]],
#    ['Oklahoma', [['votes', 7], ['winner', 'Trump']]],
#    ['Oregon', [['votes', 8], ['winner', 'Harris']]],
#    ['Pennsylvania', [['votes', 19], ['winner', 'Trump']]],
#    ['Rhode Island', [['votes', 4], ['winner', 'Harris']]],
#    ['South Carolina', [['votes', 9], ['winner', 'Trump']]],
#    ['South Dakota', [['votes', 3], ['winner', 'Trump']]],
#    ['Tennessee', [['votes', 11], ['winner', 'Trump']]],
#    ['Texas', [['votes', 40], ['winner', 'Trump']]],
#    ['Utah', [['votes', 6], ['winner', 'Trump']]],
#    ['Vermont', [['votes', 3], ['winner', 'Harris']]],
#    ['Virginia', [['votes', 13], ['winner', 'Harris']]],
#    ['Washington', [['votes', 12], ['winner', 'Harris']]],
#    ['West Virginia', [['votes', 4], ['winner', 'Trump']]],
#    ['Wisconsin', [['votes', 10], ['winner', 'Harris']]],
#    ['Wyoming', [['votes', 3], ['winner', 'Trump']]]],
#   'trump_votes': 274},
#  'frequency': 17}

# %%
import plotly.graph_objects as go
import pandas as pd

# %%
data = formatted_results[0]["combination"]['result_details']

# %%
df = pd.DataFrame(data, columns=['State', 'Info'])
df['Winner'] = df['Info'].apply(lambda x: dict(x)['winner'])
df['Votes'] = df['Info'].apply(lambda x: dict(x)['votes'])

df
# Out:
#              State                             Info  Winner  Votes
# 0          Alabama    [[votes, 9], [winner, Trump]]   Trump      9
# 1           Alaska    [[votes, 3], [winner, Trump]]   Trump      3
# 2          Arizona  [[votes, 11], [winner, Harris]]  Harris     11
# 3         Arkansas    [[votes, 6], [winner, Trump]]   Trump      6
# 4       California  [[votes, 54], [winner, Harris]]  Harris     54
# 5         Colorado  [[votes, 10], [winner, Harris]]  Harris     10
# 6      Connecticut   [[votes, 7], [winner, Harris]]  Harris      7
# 7         Delaware   [[votes, 3], [winner, Harris]]  Harris      3
# 8          Florida   [[votes, 30], [winner, Trump]]   Trump     30
# 9          Georgia   [[votes, 16], [winner, Trump]]   Trump     16
# 10          Hawaii   [[votes, 4], [winner, Harris]]  Harris      4
# 11           Idaho    [[votes, 4], [winner, Trump]]   Trump      4
# 12        Illinois  [[votes, 19], [winner, Harris]]  Harris     19
# 13         Indiana   [[votes, 11], [winner, Trump]]   Trump     11
# 14            Iowa    [[votes, 6], [winner, Trump]]   Trump      6
# 15          Kansas    [[votes, 6], [winner, Trump]]   Trump      6
# 16        Kentucky    [[votes, 8], [winner, Trump]]   Trump      8
# 17       Louisiana    [[votes, 8], [winner, Trump]]   Trump      8
# 18           Maine   [[votes, 4], [winner, Harris]]  Harris      4
# 19        Maryland  [[votes, 10], [winner, Harris]]  Harris     10
# 20   Massachusetts  [[votes, 11], [winner, Harris]]  Harris     11
# 21        Michigan  [[votes, 15], [winner, Harris]]  Harris     15
# 22       Minnesota  [[votes, 10], [winner, Harris]]  Harris     10
# 23     Mississippi    [[votes, 6], [winner, Trump]]   Trump      6
# 24        Missouri   [[votes, 10], [winner, Trump]]   Trump     10
# 25         Montana    [[votes, 4], [winner, Trump]]   Trump      4
# 26        Nebraska    [[votes, 5], [winner, Trump]]   Trump      5
# 27          Nevada    [[votes, 6], [winner, Trump]]   Trump      6
# 28   New Hampshire   [[votes, 4], [winner, Harris]]  Harris      4
# 29      New Jersey   [[votes, 14], [winner, Trump]]   Trump     14
# 30      New Mexico   [[votes, 5], [winner, Harris]]  Harris      5
# 31        New York  [[votes, 28], [winner, Harris]]  Harris     28
# 32  North Carolina  [[votes, 16], [winner, Harris]]  Harris     16
# 33    North Dakota    [[votes, 3], [winner, Trump]]   Trump      3
# 34            Ohio   [[votes, 17], [winner, Trump]]   Trump     17
# 35        Oklahoma    [[votes, 7], [winner, Trump]]   Trump      7
# 36          Oregon   [[votes, 8], [winner, Harris]]  Harris      8
# 37    Pennsylvania   [[votes, 19], [winner, Trump]]   Trump     19
# 38    Rhode Island   [[votes, 4], [winner, Harris]]  Harris      4
# 39  South Carolina    [[votes, 9], [winner, Trump]]   Trump      9
# 40    South Dakota    [[votes, 3], [winner, Trump]]   Trump      3
# 41       Tennessee   [[votes, 11], [winner, Trump]]   Trump     11
# 42           Texas   [[votes, 40], [winner, Trump]]   Trump     40
# 43            Utah    [[votes, 6], [winner, Trump]]   Trump      6
# 44         Vermont   [[votes, 3], [winner, Harris]]  Harris      3
# 45        Virginia  [[votes, 13], [winner, Harris]]  Harris     13
# 46      Washington  [[votes, 12], [winner, Harris]]  Harris     12
# 47   West Virginia    [[votes, 4], [winner, Trump]]   Trump      4
# 48       Wisconsin  [[votes, 10], [winner, Harris]]  Harris     10
# 49         Wyoming    [[votes, 3], [winner, Trump]]   Trump      3

# %%
# Create a color map
color_map = {'Trump': 'red', 'Harris': 'blue'}
df['Color'] = df['Winner'].map(color_map)
df
# Out:
#              State                             Info  Winner  Votes Color
# 0          Alabama    [[votes, 9], [winner, Trump]]   Trump      9   red
# 1           Alaska    [[votes, 3], [winner, Trump]]   Trump      3   red
# 2          Arizona  [[votes, 11], [winner, Harris]]  Harris     11  blue
# 3         Arkansas    [[votes, 6], [winner, Trump]]   Trump      6   red
# 4       California  [[votes, 54], [winner, Harris]]  Harris     54  blue
# 5         Colorado  [[votes, 10], [winner, Harris]]  Harris     10  blue
# 6      Connecticut   [[votes, 7], [winner, Harris]]  Harris      7  blue
# 7         Delaware   [[votes, 3], [winner, Harris]]  Harris      3  blue
# 8          Florida   [[votes, 30], [winner, Trump]]   Trump     30   red
# 9          Georgia   [[votes, 16], [winner, Trump]]   Trump     16   red
# 10          Hawaii   [[votes, 4], [winner, Harris]]  Harris      4  blue
# 11           Idaho    [[votes, 4], [winner, Trump]]   Trump      4   red
# 12        Illinois  [[votes, 19], [winner, Harris]]  Harris     19  blue
# 13         Indiana   [[votes, 11], [winner, Trump]]   Trump     11   red
# 14            Iowa    [[votes, 6], [winner, Trump]]   Trump      6   red
# 15          Kansas    [[votes, 6], [winner, Trump]]   Trump      6   red
# 16        Kentucky    [[votes, 8], [winner, Trump]]   Trump      8   red
# 17       Louisiana    [[votes, 8], [winner, Trump]]   Trump      8   red
# 18           Maine   [[votes, 4], [winner, Harris]]  Harris      4  blue
# 19        Maryland  [[votes, 10], [winner, Harris]]  Harris     10  blue
# 20   Massachusetts  [[votes, 11], [winner, Harris]]  Harris     11  blue
# 21        Michigan  [[votes, 15], [winner, Harris]]  Harris     15  blue
# 22       Minnesota  [[votes, 10], [winner, Harris]]  Harris     10  blue
# 23     Mississippi    [[votes, 6], [winner, Trump]]   Trump      6   red
# 24        Missouri   [[votes, 10], [winner, Trump]]   Trump     10   red
# 25         Montana    [[votes, 4], [winner, Trump]]   Trump      4   red
# 26        Nebraska    [[votes, 5], [winner, Trump]]   Trump      5   red
# 27          Nevada    [[votes, 6], [winner, Trump]]   Trump      6   red
# 28   New Hampshire   [[votes, 4], [winner, Harris]]  Harris      4  blue
# 29      New Jersey   [[votes, 14], [winner, Trump]]   Trump     14   red
# 30      New Mexico   [[votes, 5], [winner, Harris]]  Harris      5  blue
# 31        New York  [[votes, 28], [winner, Harris]]  Harris     28  blue
# 32  North Carolina  [[votes, 16], [winner, Harris]]  Harris     16  blue
# 33    North Dakota    [[votes, 3], [winner, Trump]]   Trump      3   red
# 34            Ohio   [[votes, 17], [winner, Trump]]   Trump     17   red
# 35        Oklahoma    [[votes, 7], [winner, Trump]]   Trump      7   red
# 36          Oregon   [[votes, 8], [winner, Harris]]  Harris      8  blue
# 37    Pennsylvania   [[votes, 19], [winner, Trump]]   Trump     19   red
# 38    Rhode Island   [[votes, 4], [winner, Harris]]  Harris      4  blue
# 39  South Carolina    [[votes, 9], [winner, Trump]]   Trump      9   red
# 40    South Dakota    [[votes, 3], [winner, Trump]]   Trump      3   red
# 41       Tennessee   [[votes, 11], [winner, Trump]]   Trump     11   red
# 42           Texas   [[votes, 40], [winner, Trump]]   Trump     40   red
# 43            Utah    [[votes, 6], [winner, Trump]]   Trump      6   red
# 44         Vermont   [[votes, 3], [winner, Harris]]  Harris      3  blue
# 45        Virginia  [[votes, 13], [winner, Harris]]  Harris     13  blue
# 46      Washington  [[votes, 12], [winner, Harris]]  Harris     12  blue
# 47   West Virginia    [[votes, 4], [winner, Trump]]   Trump      4   red
# 48       Wisconsin  [[votes, 10], [winner, Harris]]  Harris     10  blue
# 49         Wyoming    [[votes, 3], [winner, Trump]]   Trump      3   red

# %%
state_abbr = {
    'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ', 'Arkansas': 'AR', 'California': 'CA',
    'Colorado': 'CO', 'Connecticut': 'CT', 'Delaware': 'DE', 'Florida': 'FL', 'Georgia': 'GA',
    'Hawaii': 'HI', 'Idaho': 'ID', 'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA',
    'Kansas': 'KS', 'Kentucky': 'KY', 'Louisiana': 'LA', 'Maine': 'ME', 'Maryland': 'MD',
    'Massachusetts': 'MA', 'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS', 'Missouri': 'MO',
    'Montana': 'MT', 'Nebraska': 'NE', 'Nevada': 'NV', 'New Hampshire': 'NH', 'New Jersey': 'NJ',
    'New Mexico': 'NM', 'New York': 'NY', 'North Carolina': 'NC', 'North Dakota': 'ND', 'Ohio': 'OH',
    'Oklahoma': 'OK', 'Oregon': 'OR', 'Pennsylvania': 'PA', 'Rhode Island': 'RI', 'South Carolina': 'SC',
    'South Dakota': 'SD', 'Tennessee': 'TN', 'Texas': 'TX', 'Utah': 'UT', 'Vermont': 'VT',
    'Virginia': 'VA', 'Washington': 'WA', 'West Virginia': 'WV', 'Wisconsin': 'WI', 'Wyoming': 'WY'
}

df = pd.DataFrame(data, columns=['State', 'Info'])
df['Winner'] = df['Info'].apply(lambda x: dict(x)['winner'])
df['Votes'] = df['Info'].apply(lambda x: dict(x)['votes'])
df['State'] = df['State'].map(state_abbr)
df
# Out:
#    State                             Info  Winner  Votes
# 0     AL    [[votes, 9], [winner, Trump]]   Trump      9
# 1     AK    [[votes, 3], [winner, Trump]]   Trump      3
# 2     AZ  [[votes, 11], [winner, Harris]]  Harris     11
# 3     AR    [[votes, 6], [winner, Trump]]   Trump      6
# 4     CA  [[votes, 54], [winner, Harris]]  Harris     54
# 5     CO  [[votes, 10], [winner, Harris]]  Harris     10
# 6     CT   [[votes, 7], [winner, Harris]]  Harris      7
# 7     DE   [[votes, 3], [winner, Harris]]  Harris      3
# 8     FL   [[votes, 30], [winner, Trump]]   Trump     30
# 9     GA   [[votes, 16], [winner, Trump]]   Trump     16
# 10    HI   [[votes, 4], [winner, Harris]]  Harris      4
# 11    ID    [[votes, 4], [winner, Trump]]   Trump      4
# 12    IL  [[votes, 19], [winner, Harris]]  Harris     19
# 13    IN   [[votes, 11], [winner, Trump]]   Trump     11
# 14    IA    [[votes, 6], [winner, Trump]]   Trump      6
# 15    KS    [[votes, 6], [winner, Trump]]   Trump      6
# 16    KY    [[votes, 8], [winner, Trump]]   Trump      8
# 17    LA    [[votes, 8], [winner, Trump]]   Trump      8
# 18    ME   [[votes, 4], [winner, Harris]]  Harris      4
# 19    MD  [[votes, 10], [winner, Harris]]  Harris     10
# 20    MA  [[votes, 11], [winner, Harris]]  Harris     11
# 21    MI  [[votes, 15], [winner, Harris]]  Harris     15
# 22    MN  [[votes, 10], [winner, Harris]]  Harris     10
# 23    MS    [[votes, 6], [winner, Trump]]   Trump      6
# 24    MO   [[votes, 10], [winner, Trump]]   Trump     10
# 25    MT    [[votes, 4], [winner, Trump]]   Trump      4
# 26    NE    [[votes, 5], [winner, Trump]]   Trump      5
# 27    NV    [[votes, 6], [winner, Trump]]   Trump      6
# 28    NH   [[votes, 4], [winner, Harris]]  Harris      4
# 29    NJ   [[votes, 14], [winner, Trump]]   Trump     14
# 30    NM   [[votes, 5], [winner, Harris]]  Harris      5
# 31    NY  [[votes, 28], [winner, Harris]]  Harris     28
# 32    NC  [[votes, 16], [winner, Harris]]  Harris     16
# 33    ND    [[votes, 3], [winner, Trump]]   Trump      3
# 34    OH   [[votes, 17], [winner, Trump]]   Trump     17
# 35    OK    [[votes, 7], [winner, Trump]]   Trump      7
# 36    OR   [[votes, 8], [winner, Harris]]  Harris      8
# 37    PA   [[votes, 19], [winner, Trump]]   Trump     19
# 38    RI   [[votes, 4], [winner, Harris]]  Harris      4
# 39    SC    [[votes, 9], [winner, Trump]]   Trump      9
# 40    SD    [[votes, 3], [winner, Trump]]   Trump      3
# 41    TN   [[votes, 11], [winner, Trump]]   Trump     11
# 42    TX   [[votes, 40], [winner, Trump]]   Trump     40
# 43    UT    [[votes, 6], [winner, Trump]]   Trump      6
# 44    VT   [[votes, 3], [winner, Harris]]  Harris      3
# 45    VA  [[votes, 13], [winner, Harris]]  Harris     13
# 46    WA  [[votes, 12], [winner, Harris]]  Harris     12
# 47    WV    [[votes, 4], [winner, Trump]]   Trump      4
# 48    WI  [[votes, 10], [winner, Harris]]  Harris     10
# 49    WY    [[votes, 3], [winner, Trump]]   Trump      3

# %%
# Create the choropleth map
fig = go.Figure(data=go.Choropleth(
    locations=df['State'], 
    locationmode='USA-states', 
    z=df['Winner'].map({'Trump': 0, 'Harris': 1}),  # 0 for Trump, 1 for Harris
    text=df['State'] + '<br>Winner: ' + df['Winner'] + '<br>Votes: ' + df['Votes'].astype(str),
    hoverinfo='text',
    colorscale=[[0, 'red'], [1, 'blue']],
    showscale=False,
    marker_line_color='white',
    marker_line_width=0.5
))

# Update the layout
fig.update_layout(
    title_text='2024 US Presidential Election Results',
    geo_scope='usa',
    width=1000,
    height=600
)

# Show the map
# fig.show()

# If you want to save the map as an HTML file
fig.write_html("election_map.html")

# %%
fig.show()

# %%
from datetime import datetime

current_date = datetime.now()

formatted_date = current_date.strftime("%d_%m_%Y")

print(formatted_date)
# Out:
# 03_10_2024
